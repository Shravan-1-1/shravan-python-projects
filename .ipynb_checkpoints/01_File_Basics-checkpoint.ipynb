# %%
# 📋 DAY 4 TARGET: 5 Professional Problems
# Problem	Skill	Time
# 1	File Read/Write Basics	20 min
# 2	JSON Data Manager	30 min
# 3	Error-Proof Calculator	30 min
# 4	CSV Student Database	40 min
# 5	Complete Portfolio App	40 min

# %%
# Problem 1: File Handling Basics

# %%
print("📁 DAY 4 - PROBLEM 1: FILE HANDLING MASTER")
print("=" * 50)

# 1. WRITE FILE (Text save karna)
with open("shravan_notes.txt", "w", encoding="utf-8") as f:
    f.write("🔥 Shravan Kumar Sharma - Python Mastery Notes\n")
    f.write("Day 4: File Handling + Error Handling\n")
    f.write("Goal: Government Job + AI Developer\n")
print("✅ shravan_notes.txt SAVE ho gaya!")

# 2. READ FILE (Text padhna)
print("\n📖 File content:")
with open("shravan_notes.txt", "r", encoding="utf-8") as f:
    content = f.read()
    print(content)

# 3. APPEND (Extra lines add karna)
with open("shravan_notes.txt", "a", encoding="utf-8") as f:
    f.write("\n✅ Day 4 Problem 1 COMPLETE!\n")
    f.write("Skills: read(), write(), append()\n")
print("➕ New lines APPEND ho gaye!")

# 4. Line by line padhna
print("\n📄 Line by line:")
with open("shravan_notes.txt", "r") as f:
    for line_num, line in enumerate(f, 1):
        print(f"Line {line_num}: {line.strip()}")
