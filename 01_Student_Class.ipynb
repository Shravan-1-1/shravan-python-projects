# %%
# Problem 1: Student Class (OOP Basics)

# %%
print("🎓 DAY 3 - PROBLEM 1: STUDENT CLASS")
print("=" * 50)

class Student:
    # Constructor - har student banate time chalega
    def __init__(self, name, age):
        self.name = name        # student1.name = "Rana"
        self.age = age          # student1.age = 22
        self.marks = 0          # Default marks
        self.subjects = []      # Empty list
        print(f"✅ {name} ka student object bana!")

    # Method 1 - Subject add karna
    def add_subject(self, subject):
        self.subjects.append(subject)
        print(f"📚 {subject} add ho gaya {self.name} ke liye")

    # Method 2 - Padhai karna (marks badhana)
    def study(self, hours):
        self.marks += hours * 10  # 1 hour = 10 marks
        print(f"📖 {self.name} ne {hours}hr padhaai, Marks: {self.marks}")

    # Method 3 - Profile dikhana
    def show_profile(self):
        return f"""
👨‍🎓 {self.name} ka PROFILE
═══════════════════
Age: {self.age} saal
Marks: {self.marks}
Subjects: {len(self.subjects)} ({', '.join(self.subjects) or 'Koi nahi'})
        """.strip()

# 🔥 REAL TEST - Objects banao
print("\n" + "─"*40)

# Student 1 banao (Tera)
rana = Student("Rana", 22)
rana.add_subject("Python")
rana.add_subject("AI")
rana.study(3)  # 3 hours padhaai
print(rana.show_profile())

print("\n" + "─"*40)

# Student 2 banao (Friend ka)
amit = Student("Amit", 21)
amit.add_subject("Web Dev")
amit.study(2)
print(amit.show_profile())
# Out:
# 🎓 DAY 3 - PROBLEM 1: STUDENT CLASS
# ...
#
# ────────────────────────────────────────
# ✅ Rana ka student object bana!
# 📚 Python add ho gaya Rana ke liye
# 📚 AI add ho gaya Rana ke liye
# 📖 Rana ne 3hr padhaai, Marks: 30
# 👨‍🎓 Rana ka PROFILE
# ═══════════════════
# Age: 22 saal
# Marks: 30
# Subjects: 2 (Python, AI)
#
# ────────────────────────────────────────
# ✅ Amit ka student object bana!
# 📚 Web Dev add ho gaya Amit ke liye
# 📖 Amit ne 2hr padhaai, Marks: 20
# 👨‍🎓 Amit ka PROFILE
# ═══════════════════
# Age: 21 saal
# Marks: 20
# Subjects: 1 (Web Dev)
