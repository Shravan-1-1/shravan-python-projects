# %%
#🏆 DAY 2 COMPLETE CHECKLIST
# ✅ Problem 1: User Profile (functions, validation)
# ✅ Problem 2: Guessing Game (loops, random)
# ✅ Problem 3: Expense Tracker (JSON file I/O)
# ✅ Problem 4: Calculator (8 functions, menu)
# ⏳ Problem 5: Password Generator (string, random mastery)
